# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('food_delivery_time.csv')
df
# Out:
#        Order_ID    Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0          1000  9.68kilometer    Wndy           Low     Morning         Bike
# 1          1001       23.79 km    Fogy        Medium     Morning         Bike
# 2          1002       18.43 km    Cldy           Low       Night         Bike
# 3          1003       15.17 km    Cldy           Low     Morning      Scooter
# 4          1004        4.32 km    Cldy           Low     Evening         Bike
# ...         ...            ...     ...           ...         ...          ...
# 20445     21445       17.08 km  Rainy@          High       Night         Bike
# 20446     21446        2.73 km   Foggy        Medium     Evening          Car
# 20447     21447        4.11 km   Foggy        Medium       Night         Bike
# 20448     21448       12.97 km   Windy           Low       Night         Bike
# 20449     21449            NaN  Clear#        Medium     Evening         Bike
#
# ...

# %%
df.head()
# Out:
#    Order_ID    Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0      1000  9.68kilometer    Wndy           Low     Morning         Bike
# 1      1001       23.79 km    Fogy        Medium     Morning         Bike
# 2      1002       18.43 km    Cldy           Low       Night         Bike
# 3      1003       15.17 km    Cldy           Low     Morning      Scooter
# 4      1004        4.32 km    Cldy           Low     Evening         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                  11.0                     1.0               52.0
# 1                  17.0                     2.0              154.0
# 2                  26.0                     8.0               66.0
# 3                   NaN                     5.0               75.0
# 4                  12.0                     5.0               33.0

# %%
df.tail()
# Out:
#        Order_ID Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 20445     21445    17.08 km  Rainy@          High       Night         Bike
# 20446     21446     2.73 km   Foggy        Medium     Evening          Car
# 20447     21447     4.11 km   Foggy        Medium       Night         Bike
# 20448     21448    12.97 km   Windy           Low       Night         Bike
# 20449     21449         NaN  Clear#        Medium     Evening         Bike
#
#        Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 20445                  14.0                     6.0              104.0
# 20446                  28.0                     7.0               62.0
# 20447                  17.0                     9.0               25.0
# 20448                  12.0                     2.0               54.0
# 20449                   6.0                     7.0               96.0

# %%
df.dtypes
# Out:
# Order_ID                    int64
# Distance_km                object
# Weather                    object
# Traffic_Level              object
# Time_of_Day                object
# Vehicle_Type               object
# Preparation_Time_min      float64
# Courier_Experience_yrs    float64
# Delivery_Time_min         float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Order_ID                    0
# Distance_km               244
# Weather                   328
# Traffic_Level             284
# Time_of_Day               328
# Vehicle_Type                0
# Preparation_Time_min      390
# Courier_Experience_yrs    134
# Delivery_Time_min         240
# dtype: int64

# %%
df['Distance_km'].unique()
# Out:
# array(['9.68kilometer', '23.79 km', '18.43 km', ..., '15.39km',
#        '8.38kilometer', '10.51km'], shape=(4872,), dtype=object)

# %%
df['Distance_km']=df['Distance_km'].str.replace('KM',' ')
df['Distance_km']=df['Distance_km'].str.replace('kilometer',' ')
df['Distance_km']=df['Distance_km'].str.replace('km',' ')
df
# Out:
#        Order_ID Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0          1000       9.68     Wndy           Low     Morning         Bike
# 1          1001     23.79      Fogy        Medium     Morning         Bike
# 2          1002     18.43      Cldy           Low       Night         Bike
# 3          1003     15.17      Cldy           Low     Morning      Scooter
# 4          1004      4.32      Cldy           Low     Evening         Bike
# ...         ...         ...     ...           ...         ...          ...
# 20445     21445     17.08    Rainy@          High       Night         Bike
# 20446     21446      2.73     Foggy        Medium     Evening          Car
# 20447     21447      4.11     Foggy        Medium       Night         Bike
# 20448     21448     12.97     Windy           Low       Night         Bike
# 20449     21449         NaN  Clear#        Medium     Evening         Bike
#
# ...

# %%
df['Distance_km'].unique()
# Out:
# array(['9.68 ', '23.79  ', '18.43  ', ..., '10.83 ', '10.72 ', '8.38 '],
#       shape=(4154,), dtype=object)

# %%
df['Traffic_Level'].unique()
# Out:
# array(['Low', 'Medium', 'High', nan], dtype=object)

# %%
df['Time_of_Day'].unique()
# Out:
# array(['Morning', 'Night', 'Evening', 'Afternoon', nan], dtype=object)

# %%
df['Vehicle_Type'].unique()
# Out:
# array(['Bike', 'Scooter', 'Car'], dtype=object)

# %%
df['Weather'].unique()
# Out:
# array(['Wndy', 'Fogy', 'Cldy', 'Cloudy', 'Clear#', 'Cler', 'Clear',
#        'Cloudy#', 'Foggy', 'Windy', 'Rainy', 'Clear@', nan, 'Foggy#',
#        'Rainy#', 'Windy#', 'Cloudy@', 'Rainy@', 'Windy@', 'Foggy@'],
#       dtype=object)

# %%
df['Weather'] = df['Weather'].str.replace(r'[^A-Za-z\s]', '', regex=True)

# %%
df['Weather'].unique()
# Out:
# array(['Wndy', 'Fogy', 'Cldy', 'Cloudy', 'Clear', 'Cler', 'Foggy',
#        'Windy', 'Rainy', nan], dtype=object)

# %%
df['Weather'] = df['Weather'].replace({
    'Cldy': 'Cloudy',
    'Cler': 'Clear',
    'Fogy': 'Foggy',
    'Wndy': 'Windy',
    'Cler':'Clear',
    'Riany':'Rainy'
})

# %%
df['Weather'].unique()
# Out:
# array(['Windy', 'Foggy', 'Cloudy', 'Clear', 'Rainy', nan], dtype=object)

# %%
sns.countplot(x=df['Weather'],data=df,color='y')
plt.title("weather Count")
# Out:
# Text(0.5, 1.0, 'weather Count')

# %%
Time=df['Time_of_Day'].value_counts()
Time
# Out:
# Time_of_Day
# Evening      6133
# Morning      5997
# Afternoon    5019
# Night        2973
# Name: count, dtype: int64

# %%
plt.pie(Time.values,labels=Time.index,autopct="%.1f%%")
plt.legend(loc="upper right",bbox_to_anchor=(1.3, 1))

# %%
traffic=df['Traffic_Level'].value_counts()
traffic
# Out:
# Traffic_Level
# High      8103
# Medium    7059
# Low       5004
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.barh(traffic.index, traffic.values)
plt.xlabel("Traffic Count")
plt.ylabel("Traffic Type")
plt.title("Traffic Count")

# Invert so highest bars start at top
plt.gca().invert_yaxis()

plt.show()

# %%
Vehicle=df['Vehicle_Type'].value_counts()
Vehicle
# Out:
# Vehicle_Type
# Bike       12309
# Scooter     6138
# Car         2003
# Name: count, dtype: int64

# %%
plt.bar(Vehicle.index,height=Vehicle.values)
# Out:
# <BarContainer object of 3 artists>

# %%
sns.histplot(df['Preparation_Time_min'],kde=True)
plt.axvline(df['Preparation_Time_min'].mean(),color='red',linestyle='--',label='mean preparation time')

# %%
df.corr(numeric_only=True)
# Out:
#                         Order_ID  Preparation_Time_min  \
# Order_ID                1.000000              0.005168
# Preparation_Time_min    0.005168              1.000000
# Courier_Experience_yrs  0.014524             -0.003423
# Delivery_Time_min       0.008264              0.272486
#
#                         Courier_Experience_yrs  Delivery_Time_min
# Order_ID                              0.014524           0.008264
# Preparation_Time_min                 -0.003423           0.272486
# Courier_Experience_yrs                1.000000          -0.119752
# Delivery_Time_min                    -0.119752           1.000000

# %%
sns.heatmap(df.corr(numeric_only=True,),annot=True)
# Out:
# <Axes: >

# %%
df.drop('Order_ID',axis=1,inplace=True)

# %%
#change datatype
df['Distance_km']=df['Distance_km'].astype(float)

# %%
df.dtypes
# Out:
# Distance_km               float64
# Weather                    object
# Traffic_Level              object
# Time_of_Day                object
# Vehicle_Type               object
# Preparation_Time_min      float64
# Courier_Experience_yrs    float64
# Delivery_Time_min         float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Distance_km               244
# Weather                   328
# Traffic_Level             284
# Time_of_Day               328
# Vehicle_Type                0
# Preparation_Time_min      390
# Courier_Experience_yrs    134
# Delivery_Time_min         240
# dtype: int64

# %%
df.dropna(subset=['Delivery_Time_min'],inplace=True,ignore_index=True)

# %%
#filling misssing value
df['Distance_km']=df['Distance_km'].fillna(df['Distance_km'].mean())
df['Weather']=df['Weather'].fillna(df['Weather'].mode()[0])
df['Traffic_Level']=df['Traffic_Level'].fillna(df['Traffic_Level'].mode()[0])
df['Time_of_Day']=df['Time_of_Day'].fillna(df['Time_of_Day'].mode()[0])
df['Preparation_Time_min']=df['Preparation_Time_min'].fillna(df['Preparation_Time_min'].mean())
df['Courier_Experience_yrs']=df['Courier_Experience_yrs'].fillna(df['Courier_Experience_yrs'].mean())

# %%
df.tail()
# Out:
#        Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 20205    17.080000   Rainy          High       Night         Bike
# 20206     2.730000   Foggy        Medium     Evening          Car
# 20207     4.110000   Foggy        Medium       Night         Bike
# 20208    12.970000   Windy           Low       Night         Bike
# 20209    32.728033   Clear        Medium     Evening         Bike
#
#        Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 20205                  14.0                     6.0              104.0
# 20206                  28.0                     7.0               62.0
# 20207                  17.0                     9.0               25.0
# 20208                  12.0                     2.0               54.0
# 20209                   6.0                     7.0               96.0

# %%
df.isna().sum()
# Out:
# Distance_km               0
# Weather                   0
# Traffic_Level             0
# Time_of_Day               0
# Vehicle_Type              0
# Preparation_Time_min      0
# Courier_Experience_yrs    0
# Delivery_Time_min         0
# dtype: int64

# %%
for i in df.columns:
    if df[i].dtype=='int' or df[i].dtype=='float':
        plt.figure(figsize=(6,4))
        sns.boxplot(x=df[i])
        plt.title(f"ouliers of{i}")

# %%
#remove outlier
def remove_outlier(df,col):
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    iqr=q3-q1
    upper=q3+1.5*iqr
    lower=q1-1.5*iqr
    median=df[col].median()
    df[col]=df[col].apply(lambda x:median if x>upper or x<lower else x)
    return df

# %%
df=remove_outlier(df,'Distance_km')
df=remove_outlier(df,'Delivery_Time_min')

# %%
plt.scatter(x=df['Distance_km'],y=df['Delivery_Time_min'])

# %%
#encoding
dfe=pd.get_dummies(df[['Weather','Traffic_Level','Time_of_Day','Vehicle_Type']],drop_first=True,dtype=int)
dfe
# Out:
#        Weather_Cloudy  Weather_Foggy  Weather_Rainy  Weather_Windy  \
# 0                   0              0              0              1
# 1                   0              1              0              0
# 2                   1              0              0              0
# 3                   1              0              0              0
# 4                   1              0              0              0
# ...               ...            ...            ...            ...
# 20205               0              0              1              0
# 20206               0              1              0              0
# 20207               0              1              0              0
# 20208               0              0              0              1
# 20209               0              0              0              0
#
#        Traffic_Level_Low  Traffic_Level_Medium  Time_of_Day_Evening  \
# 0                      1                     0                    0
# ...

# %%
df.drop(['Weather','Traffic_Level','Time_of_Day','Vehicle_Type'],axis=1,inplace=True)
df
# Out:
#        Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 0         9.680000             11.000000                     1.0
# 1        23.790000             17.000000                     2.0
# 2        18.430000             26.000000                     8.0
# 3        15.170000             19.481212                     5.0
# 4         4.320000             12.000000                     5.0
# ...            ...                   ...                     ...
# 20205    17.080000             14.000000                     6.0
# 20206     2.730000             28.000000                     7.0
# 20207     4.110000             17.000000                     9.0
# 20208    12.970000             12.000000                     2.0
# 20209    32.728033              6.000000                     7.0
#
#        Delivery_Time_min
# 0                   52.0
# 1                  154.0
# 2                   66.0
# 3                   75.0
# 4                   33.0
# ...                  ...
# ...

# %%
df_1=pd.concat([df,dfe],axis=1)
df_1
# Out:
#        Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 0         9.680000             11.000000                     1.0
# 1        23.790000             17.000000                     2.0
# 2        18.430000             26.000000                     8.0
# 3        15.170000             19.481212                     5.0
# 4         4.320000             12.000000                     5.0
# ...            ...                   ...                     ...
# 20205    17.080000             14.000000                     6.0
# 20206     2.730000             28.000000                     7.0
# 20207     4.110000             17.000000                     9.0
# 20208    12.970000             12.000000                     2.0
# 20209    32.728033              6.000000                     7.0
#
#        Delivery_Time_min  Weather_Cloudy  Weather_Foggy  Weather_Rainy  \
# 0                   52.0               0              0              0
# ...

# %%
x=df_1.drop('Delivery_Time_min',axis=1)
x
# Out:
#        Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 0         9.680000             11.000000                     1.0
# 1        23.790000             17.000000                     2.0
# 2        18.430000             26.000000                     8.0
# 3        15.170000             19.481212                     5.0
# 4         4.320000             12.000000                     5.0
# ...            ...                   ...                     ...
# 20205    17.080000             14.000000                     6.0
# 20206     2.730000             28.000000                     7.0
# 20207     4.110000             17.000000                     9.0
# 20208    12.970000             12.000000                     2.0
# 20209    32.728033              6.000000                     7.0
#
#        Weather_Cloudy  Weather_Foggy  Weather_Rainy  Weather_Windy  \
# 0                   0              0              0              1
# ...

# %%
y=df_1['Delivery_Time_min']
y
# Out:
# 0         52.0
# 1        154.0
# 2         66.0
# 3         75.0
# 4         33.0
#          ...
# 20205    104.0
# 20206     62.0
# 20207     25.0
# 20208     54.0
# 20209     96.0
# Name: Delivery_Time_min, Length: 20210, dtype: float64

# %%
sns.regplot(
    x=df_1['Distance_km'],
    y=df_1['Delivery_Time_min'],
    line_kws={"color":"red","linewidth":2,"linestyle":"--"}
)

plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#        Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 15763        17.14                  13.0                     8.0
# 14083        19.09                   8.0                     1.0
# 6764         15.67                  18.0                     4.0
# 8983          6.03                  24.0                     8.0
# 17241        17.50                   6.0                     6.0
# ...            ...                   ...                     ...
# 10955        13.51                  10.0                     2.0
# 17289        23.32                  21.0                     9.0
# 5192         11.69                  28.0                     5.0
# 12172        17.15                  23.0                     1.0
# 235           4.84                  16.0                     3.0
#
#        Weather_Cloudy  Weather_Foggy  Weather_Rainy  Weather_Windy  \
# 15763               0              0              0              0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
lr=LinearRegression()
rf=RandomForestRegressor(n_estimators=100)
dr=DecisionTreeRegressor()

lst=[lr,rf,dr]

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score
for i in lst:


    i.fit(x_train,y_train)

    y_pred=i.predict(x_test)
    print("model name is:",i)
    print("-"*50)

    print("mean_absolute_error",mean_absolute_error(y_test,y_pred))
    print("mean_absolute_percentage_error",mean_absolute_percentage_error(y_test,y_pred))
    print("mean_squared_error",mean_squared_error(y_test,y_pred))
    print("r2_score",r2_score(y_test,y_pred))
    print("*"*50)
# Out:
# model name is: LinearRegression()
# --------------------------------------------------
# mean_absolute_error 9.794558468657776
# mean_absolute_percentage_error 0.14562316958867286
# mean_squared_error 295.8381259695224
# r2_score 0.8174386864367931
# **************************************************
# model name is: RandomForestRegressor()
# --------------------------------------------------
# mean_absolute_error 8.098887294518667
# mean_absolute_percentage_error 0.10856018632069026
# mean_squared_error 168.91565292200414
# r2_score 0.8957623755296343
# **************************************************
# model name is: DecisionTreeRegressor()
# --------------------------------------------------
# mean_absolute_error 11.370361207323107
# mean_absolute_percentage_error 0.15187166888610984
# mean_squared_error 303.7006844796305
# r2_score 0.8125867120509063
# **************************************************

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor(n_estimators=200)
random_forest_model.fit(x_train,y_train)
y_pred=random_forest_model.predict(x_test)
y_pred
# Out:
# array([81.09, 74.49, 93.  , ..., 50.7 , 98.01, 75.62], shape=(6063,))

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score
print("mean_absolute_error",mean_absolute_error(y_test,y_pred))
print("mean_absolute_percentage_error",mean_absolute_percentage_error(y_test,y_pred))
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print("r2_score",r2_score(y_test,y_pred))
# Out:
# mean_absolute_error 8.09116241566724
# mean_absolute_percentage_error 0.10849469944484592
# mean_squared_error 169.15687551936753
# r2_score 0.8956135173860416

# %%
import pickle
pickle.dump(random_forest_model, open("random_forest.pkl", "wb"))

# %%
# After generating training dummy variables (like dfe)
columns = x.columns
pickle.dump(columns, open("columns.pkl", "wb"))
